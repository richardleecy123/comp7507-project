# %%
from graphs import *
'''
setDataFilter
------------------------------------------------------------------------------------------------------------------------------------
1. time_range=(datetime(lower), datetime(upper))     e.g. time_range=(datetime(2017, 11, 1, 0, 0, 0),datetime(2020, 1, 1, 0, 0, 0))
2. category=[]                      e.g. category=['Trailers','Gaming','Music']
3. region=[]                       e.g. region=['US','JP']
4. rank_range=(lower, upper)               e.g. rank_range=(0.8,1)
5. channel=[]                       e.g. channel=['EminemVEVO','iDubbbzTV']

drawRadarGraph
------------------------------------------------------------------------------------------------------------------------------------
1. df_subset
2. type='channel' / type='region'             #problem: only applicable for single region or single channel
------------------------------------------------------------------------------------------------------------------------------------


'''
df_subset = setDataFilter(time_range=(datetime(2017, 11, 1, 0, 0, 0),datetime(2020, 1, 1, 0, 0, 0)), 
                            #region=['IN'],
                            #rank_range=(0,0.1)
                            )
drawWordCloud(df_subset)
#drawRadarGraph(df_subset, type='channel') 
#drawPublishTimeDistribution(df_subset)
#drawNumVideoTrend(df_subset)
#drawViewVideoTrend(df_subset)
#drawLikeVideoTrend(df_subset)
#drawDislikeVideoTrend(df_subset)
#drawCommentVideoTrend(df_subset)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x500 at 0x16A7D2D21C8>

# %%
df_subset
# Out:
#            video_id trending_date  \
# 88093   2Vv-BfVoq4g      17.15.11
# 88261   c64I9HNpiOY      17.17.11
# 88496   VXOJPfk5k9o      17.20.11
# 88801   gu_cSXf1zGo      17.24.11
# 88925   rewrhR1sKx8      17.25.11
# ...             ...           ...
# 103255  0mdP_YyqYio      18.31.05
# 103358  1nDbkfCt2t4      18.02.06
# 103586  kZUxD_pEqgg      18.05.06
# 103855  pnMQLrS5sTE      18.09.06
# 104176  64UX1npgRkI      18.14.06
#
#                                                     title channel_title  \
# 88093         Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
# 88261   Padmavati : Ek Dil Ek Jaan Video Song | Deepik...      T-Series
# 88496   Official Trailer: Bulbul | Divya Khosla Kumar ...      T-Series
# 88801   Official Trailer: Sallu Ki Shaadi | Movie Rele...      T-Series
# 88925   Song Teaser: Ik Kahani | Gajendra Verma | Vikr...      T-Series
# ...                                                   ...           ...
# ...
